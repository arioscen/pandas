# %%
import matplotlib.pyplot as plt
 
data = [2874, 1894, 1485, 1226, 1119, 985, 372, 92, 56, 8]
labels = ['Java', 'C#', 'JavaScript', 'PHP', 'C', 'C++', 'JPython', 'Ruby', 'R', 'Go']
plt.bar(range(len(data)), data, tick_label=labels, width=0.5)

plt.show()
